# %%
import pandas as pd
from os import listdir
import os

# %%
old_dir = r'C:\Workspace\VisionEval\models\VERSPM\inputs_RVMPO'

# %%
new_dir = r'C:\Workspace\VisionEval\models\VERSPM\inputs'

# %%
for fname in listdir(old_dir):
    if fname != 'geo.csv':
        df_old = pd.read_csv(os.path.join(old_dir,fname))
        df_new = pd.read_csv(os.path.join(new_dir,fname))
#         print((fname, len(df_old), len(df_new)))
        print('--------------'+fname+'----------------')
        print(df_old.describe())
        print(df_new.describe())
# Out:
# --------------azone_carsvc_characteristics.csv----------------
#              Year  HighCarSvcCost.2010  LowCarSvcCost.2010  \
# count     2.00000                  2.0                 2.0
# mean   2024.00000                  1.0                 3.0
# std      19.79899                  0.0                 0.0
# min    2010.00000                  1.0                 3.0
# 25%    2017.00000                  1.0                 3.0
# 50%    2024.00000                  1.0                 3.0
# 75%    2031.00000                  1.0                 3.0
# max    2038.00000                  1.0                 3.0
#
#        AveCarSvcVehicleAge  LtTrkCarSvcSubProp  AutoCarSvcSubProp
# count             2.000000                2.00                2.0
# mean              2.500000                0.75                1.0
# std               0.707107                0.00                0.0
# min               2.000000                0.75                1.0
# ...

# %%
fname = "bzone_urban-town_du_proportions.csv"

# %%
df_old = pd.read_csv(r'https://raw.githubusercontent.com/VisionEval/VisionEval/master/sources/models/VERSPM/inputs//'+fname)

# %%
# df_new.sum(axis=1)
# df_old[['HhPropIncQ1','HhPropIncQ2','HhPropIncQ3','HhPropIncQ4']].sum(axis=1)
df_old.describe()
# Out:
#               Year  PropUrbanSFDU  PropUrbanMFDU  PropUrbanGQDU  PropTownSFDU  \
# count   210.000000     210.000000          210.0          210.0         210.0
# mean   2024.000000       0.829465            1.0            1.0           0.0
# std      14.033453       0.315198            0.0            0.0           0.0
# min    2010.000000       0.000000            1.0            1.0           0.0
# 25%    2010.000000       0.832252            1.0            1.0           0.0
# 50%    2024.000000       1.000000            1.0            1.0           0.0
# 75%    2038.000000       1.000000            1.0            1.0           0.0
# max    2038.000000       1.000000            1.0            1.0           0.0
#
#        PropTownMFDU  PropTownGQDU
# count         210.0         210.0
# mean            0.0           0.0
# std             0.0           0.0
# min             0.0           0.0
# 25%             0.0           0.0
# 50%             0.0           0.0
# ...

# %%
df_old.head()
# Out:
#              Geo  Year  PropUrbanSFDU  PropUrbanMFDU  PropUrbanGQDU  \
# 0  D410290014002  2010       0.468694              1              1
# 1  D410290013012  2010       0.886076              1              1
# 2  D410290014001  2010       0.862661              1              1
# 3  D410290014003  2010       0.990614              1              1
# 4  D410290013021  2010       0.014760              1              1
#
#    PropTownSFDU  PropTownMFDU  PropTownGQDU
# 0             0             0             0
# 1             0             0             0
# 2             0             0             0
# 3             0             0             0
# 4             0             0             0

# %%
df_new = pd.read_csv(r'C:\Workspace\VisionEval\models\VERSPM\inputs\\'+fname)

# %%
df_new.describe()
# Out:
#                 Geo         Year  PropUrbanSFDU  PropUrbanMFDU  PropUrbanGQDU  \
# count  5.856000e+03  5856.000000    5856.000000    5856.000000         5856.0
# mean   5.304291e+11  2034.000000       0.746155       0.485784            0.0
# std    1.192936e+08    16.001366       0.422984       0.499717            0.0
# min    5.303300e+11  2018.000000       0.000000       0.000000            0.0
# 25%    5.303302e+11  2018.000000       0.386287       0.000000            0.0
# 50%    5.303303e+11  2034.000000       1.000000       0.000000            0.0
# 75%    5.305307e+11  2050.000000       1.000000       1.000000            0.0
# max    5.306199e+11  2050.000000       1.000000       1.000000            0.0
#
#        PropTownSFDU  PropTownMFDU  PropTownGQDU
# count   5856.000000   5856.000000        5856.0
# mean       0.081378      0.041272           0.0
# std        0.260322      0.198732           0.0
# min        0.000000      0.000000           0.0
# ...

# %%
df_new.describe()
# Out:
#                 Geo         Year  PropUrbanSFDU  PropUrbanMFDU  PropUrbanGQDU  \
# count  5.856000e+03  5856.000000    5856.000000    5856.000000         5856.0
# mean   5.304291e+11  2034.000000       0.746155       0.485784            0.0
# std    1.192936e+08    16.001366       0.422984       0.499717            0.0
# min    5.303300e+11  2018.000000       0.000000       0.000000            0.0
# 25%    5.303302e+11  2018.000000       0.386287       0.000000            0.0
# 50%    5.303303e+11  2034.000000       1.000000       0.000000            0.0
# 75%    5.305307e+11  2050.000000       1.000000       1.000000            0.0
# max    5.306199e+11  2050.000000       1.000000       1.000000            0.0
#
#        PropTownSFDU  PropTownMFDU  PropTownGQDU
# count   5856.000000   5856.000000        5856.0
# mean       0.081378      0.041272           0.0
# std        0.260322      0.198732           0.0
# min        0.000000      0.000000           0.0
# ...

# %%
df_new
# Out:
#                Geo  Year  HhPropIncQ1  HhPropIncQ2  HhPropIncQ3  HhPropIncQ4
# 0     530330001011  2018     0.507503     0.278308     0.105048     0.109141
# 1     530330001012  2018     0.531479     0.327965     0.073206     0.067350
# 2     530330001013  2018     0.493716     0.350090     0.082585     0.073609
# 3     530330001021  2018     0.112546     0.164207     0.350554     0.372694
# 4     530330001022  2018     0.425403     0.167339     0.189516     0.217742
# ...            ...   ...          ...          ...          ...          ...
# 5851  530530726035  2050     0.000000     0.000000     0.000000     0.000000
# 5852  530530729031  2050     0.000000     0.000000     0.000000     0.000000
# 5853  530530729072  2050     0.000000     0.000000     0.000000     0.000000
# 5854  530530729082  2050     0.000000     0.000000     0.000000     0.000000
# 5855  530619901000  2050     0.000000     0.000000     0.000000     0.000000
#
# [5856 rows x 6 columns]

# %%
df_hh = pd.read_csv(r'C:\Workspace\VisionEval\models\VERSPM\inputs\bzone_dwelling_units.csv')

# %%
len(df_hh)
# Out:
# 5856

# %%
df2 = pd.read_csv(r'C:\Workspace\VisionEval\models\VERSPM\inputs\bzone_urban-town_du_proportions.csv')

# %%
len(df2)
# Out:
# 5856

# %%
df_geo = pd.read_csv(r'C:\Workspace\VisionEval\models\VERSPM\defs\geo.csv')

# %%
len(df_geo)*2
# Out:
# 5856

# %%
df_geo
# Out:
#      Azone         Bzone  Czone Marea
# 0     PSRC  530330001011      0  PSRC
# 1     PSRC  530330001012      1  PSRC
# 2     PSRC  530330001013      2  PSRC
# 3     PSRC  530330001021      3  PSRC
# 4     PSRC  530330001022      4  PSRC
# ...    ...           ...    ...   ...
# 2923  PSRC  530619400021   2923  PSRC
# 2924  PSRC  530619400022   2924  PSRC
# 2925  PSRC  530619400023   2925  PSRC
# 2926  PSRC  530619900020   2926  PSRC
# 2927  PSRC  530619901000   2927  PSRC
#
# [2928 rows x 4 columns]
